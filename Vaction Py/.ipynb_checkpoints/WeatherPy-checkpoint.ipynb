# %%
#Import Dependencies
import gmaps 
import pandas as pd
import json
import requests 
from citipy import citipy
import matplotlib.pyplot as plt
import time
from scipy.stats import linregress
from api_keys import weather_api_key,g_key
import numpy as np
from datetime import date

# %%
output_data_file = "output_data/cities.csv"
#Range of latitude and Longitude 
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
#Generate City Lists using CitiPy
#Create Lists to hold Laititude and Longitude and Cities
lat_lngs = []
cities = []

#Creat Random Lats and Lngs
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

#Identify Nearest City 
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    #only add unique cities
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 622

# %%
unites='imperial'
count = 1
City_name=[]
Temperature=[]
Humidity=[]
Cloudiness=[]
Wind_Speed=[]
Latitude=[]
lng=[]

print('------------------------------')
print('Start of Records')
print('------------------------------')

for city in cities:
    try:
        url=f'http://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}&units={unites}'
        response=requests.get(url).json()
        City_name.append(response['name'])
        Latitude.append(response["coord"]["lat"])
        lng.append(response['coord']['lat'])
        Temperature.append(response['main']['temp'])
        Humidity.append(response['main']['humidity'])
        Wind_Speed.append(response['wind']['speed'])
        Cloudiness.append(response['clouds']['all'])
        print(f'City Record {count} of {len(cities)} complete. | Added {city}')
        count += 1
    
    except KeyError:
        print(f'Missing data in City Record {count} of {len(cities)}. | Skipping {city}')
        count += 1
print('------------------------------')
print('End of Records')
print('------------------------------')
# Out:
# ------------------------------
# Start of Records
# ------------------------------
# City Record 1 of 622 complete. | Added saint-philippe
# City Record 2 of 622 complete. | Added hambantota
# City Record 3 of 622 complete. | Added kaitangata
# Missing data in City Record 4 of 622. | Skipping vaitupu
# City Record 5 of 622 complete. | Added saskylakh
# Missing data in City Record 6 of 622. | Skipping toulepleu
# City Record 7 of 622 complete. | Added arraial do cabo
# City Record 8 of 622 complete. | Added henties bay
# City Record 9 of 622 complete. | Added ribeira grande
# City Record 10 of 622 complete. | Added mnogovershinnyy
# City Record 11 of 622 complete. | Added butaritari
# City Record 12 of 622 complete. | Added busselton
# City Record 13 of 622 complete. | Added punta arenas
# City Record 14 of 622 complete. | Added ambulu
# City Record 15 of 622 complete. | Added baykit
# City Record 16 of 622 complete. | Added yellowknife
# City Record 17 of 622 complete. | Added rikitea
# City Record 18 of 622 complete. | Added klaksvik
# City Record 19 of 622 complete. | Added qaanaaq
# Missing data in City Record 20 of 622. | Skipping nizhneyansk
# City Record 21 of 622 complete. | Added mataura
# City Record 22 of 622 complete. | Added los llanos de aridane
# City Record 23 of 622 complete. | Added lagoa
# Missing data in City Record 24 of 622. | Skipping amderma
# City Record 25 of 622 complete. | Added hermanus
# City Record 26 of 622 complete. | Added albany
# City Record 27 of 622 complete. | Added atuona
# City Record 28 of 622 complete. | Added tekeli
# Missing data in City Record 29 of 622. | Skipping mouzakion
# City Record 30 of 622 complete. | Added yingkou
# City Record 31 of 622 complete. | Added cape town
# City Record 32 of 622 complete. | Added tuktoyaktuk
# City Record 33 of 622 complete. | Added rorvik
# City Record 34 of 622 complete. | Added itarema
# City Record 35 of 622 complete. | Added georgetown
# City Record 36 of 622 complete. | Added srednekolymsk
# Missing data in City Record 37 of 622. | Skipping belushya guba
# City Record 38 of 622 complete. | Added marsh harbour
# City Record 39 of 622 complete. | Added novopskov
# City Record 40 of 622 complete. | Added port alfred
# City Record 41 of 622 complete. | Added vaini
# City Record 42 of 622 complete. | Added campina grande
# City Record 43 of 622 complete. | Added paita
# City Record 44 of 622 complete. | Added chuy
# City Record 45 of 622 complete. | Added itoman
# Missing data in City Record 46 of 622. | Skipping taolanaro
# City Record 47 of 622 complete. | Added benguela
# City Record 48 of 622 complete. | Added ushuaia
# City Record 49 of 622 complete. | Added upernavik
# City Record 50 of 622 complete. | Added aklavik
# City Record 51 of 622 complete. | Added uglovskoye
# City Record 52 of 622 complete. | Added tautira
# City Record 53 of 622 complete. | Added niteroi
# City Record 54 of 622 complete. | Added umm kaddadah
# City Record 55 of 622 complete. | Added hamilton
# City Record 56 of 622 complete. | Added vanimo
# City Record 57 of 622 complete. | Added sakakah
# City Record 58 of 622 complete. | Added notre-dame-du-lac
# City Record 59 of 622 complete. | Added saint-augustin
# City Record 60 of 622 complete. | Added dakar
# City Record 61 of 622 complete. | Added ciudad ojeda
# City Record 62 of 622 complete. | Added san jose
# City Record 63 of 622 complete. | Added marienburg
# City Record 64 of 622 complete. | Added bredasdorp
# City Record 65 of 622 complete. | Added vestmanna
# City Record 66 of 622 complete. | Added kenai
# City Record 67 of 622 complete. | Added hailar
# City Record 68 of 622 complete. | Added scarborough
# Missing data in City Record 69 of 622. | Skipping tuggurt
# City Record 70 of 622 complete. | Added ixtapa
# City Record 71 of 622 complete. | Added puerto wilches
# City Record 72 of 622 complete. | Added ahipara
# City Record 73 of 622 complete. | Added kapaa
# City Record 74 of 622 complete. | Added puerto carreno
# City Record 75 of 622 complete. | Added paamiut
# City Record 76 of 622 complete. | Added inuvik
# City Record 77 of 622 complete. | Added barrow
# City Record 78 of 622 complete. | Added nikolskoye
# City Record 79 of 622 complete. | Added lavrentiya
# City Record 80 of 622 complete. | Added pangnirtung
# City Record 81 of 622 complete. | Added solnechnyy
# City Record 82 of 622 complete. | Added wajima
# City Record 83 of 622 complete. | Added kodiak
# City Record 84 of 622 complete. | Added merauke
# City Record 85 of 622 complete. | Added padang
# City Record 86 of 622 complete. | Added labuhan
# City Record 87 of 622 complete. | Added davila
# City Record 88 of 622 complete. | Added alexandria
# Missing data in City Record 89 of 622. | Skipping illoqqortoormiut
# City Record 90 of 622 complete. | Added isangel
# City Record 91 of 622 complete. | Added port keats
# City Record 92 of 622 complete. | Added narsaq
# City Record 93 of 622 complete. | Added udachnyy
# City Record 94 of 622 complete. | Added pevek
# City Record 95 of 622 complete. | Added jalu
# City Record 96 of 622 complete. | Added arman
# City Record 97 of 622 complete. | Added san patricio
# City Record 98 of 622 complete. | Added marawi
# City Record 99 of 622 complete. | Added kars
# City Record 100 of 622 complete. | Added ratnagiri
# City Record 101 of 622 complete. | Added coihaique
# City Record 102 of 622 complete. | Added monte alegre de sergipe
# City Record 103 of 622 complete. | Added lorengau
# City Record 104 of 622 complete. | Added faanui
# Missing data in City Record 105 of 622. | Skipping barentsburg
# City Record 106 of 622 complete. | Added castro
# Missing data in City Record 107 of 622. | Skipping chagda
# City Record 108 of 622 complete. | Added mecca
# Missing data in City Record 109 of 622. | Skipping sentyabrskiy
# City Record 110 of 622 complete. | Added bluff
# City Record 111 of 622 complete. | Added mount gambier
# Missing data in City Record 112 of 622. | Skipping mys shmidta
# City Record 113 of 622 complete. | Added beaverlodge
# City Record 114 of 622 complete. | Added luderitz
# City Record 115 of 622 complete. | Added lebu
# City Record 116 of 622 complete. | Added ugoofaaru
# City Record 117 of 622 complete. | Added iqaluit
# City Record 118 of 622 complete. | Added ilulissat
# City Record 119 of 622 complete. | Added bethel
# City Record 120 of 622 complete. | Added port elizabeth
# City Record 121 of 622 complete. | Added geraldton
# City Record 122 of 622 complete. | Added shimoda
# City Record 123 of 622 complete. | Added zhigansk
# City Record 124 of 622 complete. | Added salalah
# City Record 125 of 622 complete. | Added qaqortoq
# City Record 126 of 622 complete. | Added guerrero negro
# City Record 127 of 622 complete. | Added hasaki
# City Record 128 of 622 complete. | Added cumra
# City Record 129 of 622 complete. | Added dongsheng
# City Record 130 of 622 complete. | Added chernyshevskiy
# City Record 131 of 622 complete. | Added norman wells
# City Record 132 of 622 complete. | Added touros
# City Record 133 of 622 complete. | Added zaria
# City Record 134 of 622 complete. | Added sao mateus do sul
# City Record 135 of 622 complete. | Added saint-joseph
# City Record 136 of 622 complete. | Added cabo san lucas
# City Record 137 of 622 complete. | Added kurumkan
# City Record 138 of 622 complete. | Added ariquemes
# Missing data in City Record 139 of 622. | Skipping tumannyy
# City Record 140 of 622 complete. | Added khatanga
# City Record 141 of 622 complete. | Added sibolga
# City Record 142 of 622 complete. | Added olafsvik
# City Record 143 of 622 complete. | Added nyurba
# Missing data in City Record 144 of 622. | Skipping grand river south east
# City Record 145 of 622 complete. | Added hithadhoo
# City Record 146 of 622 complete. | Added saint george
# City Record 147 of 622 complete. | Added sioux lookout
# City Record 148 of 622 complete. | Added poum
# City Record 149 of 622 complete. | Added shiraz
# City Record 150 of 622 complete. | Added maymyo
# City Record 151 of 622 complete. | Added ponta do sol
# City Record 152 of 622 complete. | Added sitka
# City Record 153 of 622 complete. | Added havelock
# City Record 154 of 622 complete. | Added kahului
# City Record 155 of 622 complete. | Added atambua
# City Record 156 of 622 complete. | Added bodden town
# City Record 157 of 622 complete. | Added vangaindrano
# City Record 158 of 622 complete. | Added cidreira
# City Record 159 of 622 complete. | Added san isidro
# City Record 160 of 622 complete. | Added tianpeng
# City Record 161 of 622 complete. | Added rapid valley
# City Record 162 of 622 complete. | Added jamestown
# City Record 163 of 622 complete. | Added ha giang
# City Record 164 of 622 complete. | Added longyearbyen
# City Record 165 of 622 complete. | Added thompson
# City Record 166 of 622 complete. | Added comodoro rivadavia
# City Record 167 of 622 complete. | Added vieux-habitants
# City Record 168 of 622 complete. | Added saldanha
# City Record 169 of 622 complete. | Added mar del plata
# City Record 170 of 622 complete. | Added apam
# City Record 171 of 622 complete. | Added karratha
# City Record 172 of 622 complete. | Added darhan
# City Record 173 of 622 complete. | Added rawson
# City Record 174 of 622 complete. | Added acari
# City Record 175 of 622 complete. | Added helong
# City Record 176 of 622 complete. | Added togur
# City Record 177 of 622 complete. | Added la reforma
# City Record 178 of 622 complete. | Added torbay
# City Record 179 of 622 complete. | Added kupang
# City Record 180 of 622 complete. | Added naze
# City Record 181 of 622 complete. | Added ayan
# City Record 182 of 622 complete. | Added avera
# City Record 183 of 622 complete. | Added marsa matruh
# Missing data in City Record 184 of 622. | Skipping fort saint john
# City Record 185 of 622 complete. | Added hobart
# City Record 186 of 622 complete. | Added hilo
# City Record 187 of 622 complete. | Added gizo
# City Record 188 of 622 complete. | Added pangody
# City Record 189 of 622 complete. | Added urumqi
# Missing data in City Record 190 of 622. | Skipping toungoo
# City Record 191 of 622 complete. | Added presidente bernardes
# City Record 192 of 622 complete. | Added kargopol
# City Record 193 of 622 complete. | Added nuuk
# City Record 194 of 622 complete. | Added chimore
# City Record 195 of 622 complete. | Added linhares
# City Record 196 of 622 complete. | Added bengkulu
# City Record 197 of 622 complete. | Added new norfolk
# City Record 198 of 622 complete. | Added pacific grove
# City Record 199 of 622 complete. | Added constitucion
# City Record 200 of 622 complete. | Added lima
# City Record 201 of 622 complete. | Added sao filipe
# City Record 202 of 622 complete. | Added kaeo
# City Record 203 of 622 complete. | Added saint-pierre
# City Record 204 of 622 complete. | Added sisophon
# City Record 205 of 622 complete. | Added trimbak
# City Record 206 of 622 complete. | Added samarkand
# City Record 207 of 622 complete. | Added nome
# City Record 208 of 622 complete. | Added chokurdakh
# City Record 209 of 622 complete. | Added rio branco
# City Record 210 of 622 complete. | Added almora
# City Record 211 of 622 complete. | Added marystown
# City Record 212 of 622 complete. | Added dabat
# City Record 213 of 622 complete. | Added severo-kurilsk
# City Record 214 of 622 complete. | Added ust-tsilma
# City Record 215 of 622 complete. | Added del pilar
# City Record 216 of 622 complete. | Added san luis
# City Record 217 of 622 complete. | Added susehri
# City Record 218 of 622 complete. | Added bogoslovka
# City Record 219 of 622 complete. | Added sinnamary
# City Record 220 of 622 complete. | Added kununurra
# City Record 221 of 622 complete. | Added mongoumba
# Missing data in City Record 222 of 622. | Skipping tsihombe
# City Record 223 of 622 complete. | Added hami
# City Record 224 of 622 complete. | Added forssa
# City Record 225 of 622 complete. | Added robertsport
# Missing data in City Record 226 of 622. | Skipping samusu
# City Record 227 of 622 complete. | Added ghanzi
# City Record 228 of 622 complete. | Added sirmaur
# City Record 229 of 622 complete. | Added isabela
# City Record 230 of 622 complete. | Added ponta delgada
# City Record 231 of 622 complete. | Added quatre cocos
# City Record 232 of 622 complete. | Added meulaboh
# City Record 233 of 622 complete. | Added codrington
# Missing data in City Record 234 of 622. | Skipping ngukurr
# Missing data in City Record 235 of 622. | Skipping attawapiskat
# City Record 236 of 622 complete. | Added maarianhamina
# City Record 237 of 622 complete. | Added gao
# City Record 238 of 622 complete. | Added moletai
# City Record 239 of 622 complete. | Added tchollire
# City Record 240 of 622 complete. | Added beaupre
# City Record 241 of 622 complete. | Added east london
# City Record 242 of 622 complete. | Added hofn
# City Record 243 of 622 complete. | Added sijunjung
# City Record 244 of 622 complete. | Added airai
# City Record 245 of 622 complete. | Added ndjole
# City Record 246 of 622 complete. | Added civitavecchia
# City Record 247 of 622 complete. | Added aykhal
# City Record 248 of 622 complete. | Added puerto baquerizo moreno
# Missing data in City Record 249 of 622. | Skipping karaul
# City Record 250 of 622 complete. | Added cockburn town
# City Record 251 of 622 complete. | Added iskateley
# City Record 252 of 622 complete. | Added caravelas
# Missing data in City Record 253 of 622. | Skipping meyungs
# City Record 254 of 622 complete. | Added nago
# City Record 255 of 622 complete. | Added aksay
# City Record 256 of 622 complete. | Added puerto ayora
# City Record 257 of 622 complete. | Added mersing
# City Record 258 of 622 complete. | Added bage
# Missing data in City Record 259 of 622. | Skipping bolungarvik
# Missing data in City Record 260 of 622. | Skipping barawe
# City Record 261 of 622 complete. | Added guymon
# City Record 262 of 622 complete. | Added tres arroyos
# City Record 263 of 622 complete. | Added maple creek
# City Record 264 of 622 complete. | Added port hueneme
# Missing data in City Record 265 of 622. | Skipping sinkat
# City Record 266 of 622 complete. | Added carnarvon
# City Record 267 of 622 complete. | Added campeche
# City Record 268 of 622 complete. | Added porosozero
# City Record 269 of 622 complete. | Added leningradskiy
# City Record 270 of 622 complete. | Added vagay
# Missing data in City Record 271 of 622. | Skipping tabiauea
# City Record 272 of 622 complete. | Added faya
# City Record 273 of 622 complete. | Added san andres
# City Record 274 of 622 complete. | Added port blair
# City Record 275 of 622 complete. | Added rio grande
# City Record 276 of 622 complete. | Added mbaiki
# City Record 277 of 622 complete. | Added bilibino
# City Record 278 of 622 complete. | Added abu dhabi
# City Record 279 of 622 complete. | Added port lincoln
# City Record 280 of 622 complete. | Added waingapu
# City Record 281 of 622 complete. | Added berlin
# City Record 282 of 622 complete. | Added san vicente
# City Record 283 of 622 complete. | Added were ilu
# City Record 284 of 622 complete. | Added fortuna
# Missing data in City Record 285 of 622. | Skipping khormuj
# City Record 286 of 622 complete. | Added port macquarie
# City Record 287 of 622 complete. | Added beringovskiy
# City Record 288 of 622 complete. | Added iracoubo
# City Record 289 of 622 complete. | Added dikson
# City Record 290 of 622 complete. | Added beloha
# City Record 291 of 622 complete. | Added palu
# City Record 292 of 622 complete. | Added agadez
# City Record 293 of 622 complete. | Added farakka
# City Record 294 of 622 complete. | Added mahebourg
# City Record 295 of 622 complete. | Added portland
# City Record 296 of 622 complete. | Added taoudenni
# City Record 297 of 622 complete. | Added laguna
# City Record 298 of 622 complete. | Added stolin
# City Record 299 of 622 complete. | Added menzelinsk
# City Record 300 of 622 complete. | Added katsuura
# City Record 301 of 622 complete. | Added coquimbo
# City Record 302 of 622 complete. | Added rudbar
# City Record 303 of 622 complete. | Added manta
# City Record 304 of 622 complete. | Added shenjiamen
# City Record 305 of 622 complete. | Added atbasar
# Missing data in City Record 306 of 622. | Skipping felidhoo
# Missing data in City Record 307 of 622. | Skipping candawaga
# City Record 308 of 622 complete. | Added san policarpo
# Missing data in City Record 309 of 622. | Skipping daxian
# City Record 310 of 622 complete. | Added provideniya
# City Record 311 of 622 complete. | Added calama
# City Record 312 of 622 complete. | Added esperance
# City Record 313 of 622 complete. | Added avarua
# City Record 314 of 622 complete. | Added asfi
# City Record 315 of 622 complete. | Added sabha
# Missing data in City Record 316 of 622. | Skipping zolotinka
# City Record 317 of 622 complete. | Added kisangani
# City Record 318 of 622 complete. | Added vardo
# City Record 319 of 622 complete. | Added egvekinot
# City Record 320 of 622 complete. | Added torbat-e jam
# City Record 321 of 622 complete. | Added alofi
# City Record 322 of 622 complete. | Added nishihara
# City Record 323 of 622 complete. | Added nemuro
# City Record 324 of 622 complete. | Added trancoso
# City Record 325 of 622 complete. | Added vokhtoga
# City Record 326 of 622 complete. | Added pisco
# City Record 327 of 622 complete. | Added trairi
# City Record 328 of 622 complete. | Added qujing
# City Record 329 of 622 complete. | Added ossipee
# City Record 330 of 622 complete. | Added allapalli
# City Record 331 of 622 complete. | Added cabuyaro
# City Record 332 of 622 complete. | Added tenkodogo
# City Record 333 of 622 complete. | Added progreso
# City Record 334 of 622 complete. | Added cedar city
# City Record 335 of 622 complete. | Added vostok
# City Record 336 of 622 complete. | Added lira
# City Record 337 of 622 complete. | Added bekessamson
# City Record 338 of 622 complete. | Added mumbwa
# City Record 339 of 622 complete. | Added pilar
# City Record 340 of 622 complete. | Added lagunas
# City Record 341 of 622 complete. | Added kathua
# City Record 342 of 622 complete. | Added san blas
# Missing data in City Record 343 of 622. | Skipping richard toll
# City Record 344 of 622 complete. | Added orange cove
# City Record 345 of 622 complete. | Added harper
# City Record 346 of 622 complete. | Added rundu
# City Record 347 of 622 complete. | Added tasiilaq
# City Record 348 of 622 complete. | Added shelby
# Missing data in City Record 349 of 622. | Skipping malwan
# City Record 350 of 622 complete. | Added bukavu
# City Record 351 of 622 complete. | Added thinadhoo
# City Record 352 of 622 complete. | Added cairns
# City Record 353 of 622 complete. | Added lasa
# City Record 354 of 622 complete. | Added victoria
# City Record 355 of 622 complete. | Added guarapari
# City Record 356 of 622 complete. | Added kolokani
# City Record 357 of 622 complete. | Added omboue
# City Record 358 of 622 complete. | Added laukaa
# City Record 359 of 622 complete. | Added sao felix do xingu
# City Record 360 of 622 complete. | Added amos
# Missing data in City Record 361 of 622. | Skipping barbar
# City Record 362 of 622 complete. | Added vagamo
# City Record 363 of 622 complete. | Added petropavlovsk-kamchatskiy
# City Record 364 of 622 complete. | Added mahibadhoo
# City Record 365 of 622 complete. | Added alice springs
# City Record 366 of 622 complete. | Added kawalu
# City Record 367 of 622 complete. | Added aden
# City Record 368 of 622 complete. | Added tibacuy
# City Record 369 of 622 complete. | Added sorong
# City Record 370 of 622 complete. | Added sayyan
# City Record 371 of 622 complete. | Added standerton
# City Record 372 of 622 complete. | Added anadyr
# City Record 373 of 622 complete. | Added belyy yar
# City Record 374 of 622 complete. | Added ostrovnoy
# City Record 375 of 622 complete. | Added warmbad
# City Record 376 of 622 complete. | Added segezha
# City Record 377 of 622 complete. | Added bobcaygeon
# City Record 378 of 622 complete. | Added porto santo
# City Record 379 of 622 complete. | Added atasu
# Missing data in City Record 380 of 622. | Skipping ust-kamchatsk
# City Record 381 of 622 complete. | Added rusape
# City Record 382 of 622 complete. | Added nanortalik
# City Record 383 of 622 complete. | Added dingle
# City Record 384 of 622 complete. | Added kavieng
# City Record 385 of 622 complete. | Added cherskiy
# Missing data in City Record 386 of 622. | Skipping blensong
# City Record 387 of 622 complete. | Added carutapera
# City Record 388 of 622 complete. | Added sabang
# City Record 389 of 622 complete. | Added betsiamites
# City Record 390 of 622 complete. | Added zaraza
# City Record 391 of 622 complete. | Added vila franca do campo
# City Record 392 of 622 complete. | Added shirgaon
# City Record 393 of 622 complete. | Added hauterive
# City Record 394 of 622 complete. | Added lashio
# City Record 395 of 622 complete. | Added adrar
# City Record 396 of 622 complete. | Added talnakh
# City Record 397 of 622 complete. | Added shumskiy
# City Record 398 of 622 complete. | Added muroto
# City Record 399 of 622 complete. | Added bombay
# City Record 400 of 622 complete. | Added bonfim
# City Record 401 of 622 complete. | Added kismayo
# City Record 402 of 622 complete. | Added sena madureira
# City Record 403 of 622 complete. | Added shingu
# City Record 404 of 622 complete. | Added antofagasta
# City Record 405 of 622 complete. | Added san ramon
# City Record 406 of 622 complete. | Added outjo
# City Record 407 of 622 complete. | Added la ronge
# City Record 408 of 622 complete. | Added bud
# City Record 409 of 622 complete. | Added monforte de lemos
# City Record 410 of 622 complete. | Added lensk
# City Record 411 of 622 complete. | Added bambous virieux
# City Record 412 of 622 complete. | Added husavik
# City Record 413 of 622 complete. | Added manacapuru
# City Record 414 of 622 complete. | Added beatrice
# City Record 415 of 622 complete. | Added asau
# City Record 416 of 622 complete. | Added sur
# City Record 417 of 622 complete. | Added grindavik
# City Record 418 of 622 complete. | Added tomatlan
# City Record 419 of 622 complete. | Added san cristobal
# City Record 420 of 622 complete. | Added half moon bay
# City Record 421 of 622 complete. | Added antalaha
# City Record 422 of 622 complete. | Added lerwick
# City Record 423 of 622 complete. | Added minot
# City Record 424 of 622 complete. | Added rock sound
# City Record 425 of 622 complete. | Added soller
# City Record 426 of 622 complete. | Added boddam
# City Record 427 of 622 complete. | Added aitape
# City Record 428 of 622 complete. | Added dhidhdhoo
# City Record 429 of 622 complete. | Added kavaratti
# City Record 430 of 622 complete. | Added hwange
# City Record 431 of 622 complete. | Added esil
# City Record 432 of 622 complete. | Added alta floresta
# City Record 433 of 622 complete. | Added broome
# City Record 434 of 622 complete. | Added wanxian
# City Record 435 of 622 complete. | Added kruisfontein
# City Record 436 of 622 complete. | Added teya
# City Record 437 of 622 complete. | Added bianzhuang
# City Record 438 of 622 complete. | Added alugan
# City Record 439 of 622 complete. | Added raymondville
# City Record 440 of 622 complete. | Added bathsheba
# City Record 441 of 622 complete. | Added baruun-urt
# City Record 442 of 622 complete. | Added florence
# City Record 443 of 622 complete. | Added muros
# Missing data in City Record 444 of 622. | Skipping bargal
# City Record 445 of 622 complete. | Added esso
# City Record 446 of 622 complete. | Added kungurtug
# City Record 447 of 622 complete. | Added acapulco
# City Record 448 of 622 complete. | Added tubmanburg
# City Record 449 of 622 complete. | Added nha trang
# City Record 450 of 622 complete. | Added belaya gora
# City Record 451 of 622 complete. | Added vila velha
# City Record 452 of 622 complete. | Added clocolan
# City Record 453 of 622 complete. | Added bam
# City Record 454 of 622 complete. | Added waipawa
# City Record 455 of 622 complete. | Added tiksi
# City Record 456 of 622 complete. | Added nantucket
# City Record 457 of 622 complete. | Added mao
# Missing data in City Record 458 of 622. | Skipping solovetskiy
# City Record 459 of 622 complete. | Added tuatapere
# City Record 460 of 622 complete. | Added shebunino
# City Record 461 of 622 complete. | Added chute-aux-outardes
# Missing data in City Record 462 of 622. | Skipping kamenskoye
# City Record 463 of 622 complete. | Added long xuyen
# City Record 464 of 622 complete. | Added hereford
# City Record 465 of 622 complete. | Added cap malheureux
# City Record 466 of 622 complete. | Added osias
# City Record 467 of 622 complete. | Added kuchaman
# City Record 468 of 622 complete. | Added waitati
# City Record 469 of 622 complete. | Added santa vitoria do palmar
# City Record 470 of 622 complete. | Added bairiki
# City Record 471 of 622 complete. | Added weligama
# Missing data in City Record 472 of 622. | Skipping umzimvubu
# City Record 473 of 622 complete. | Added umm lajj
# City Record 474 of 622 complete. | Added kalmunai
# City Record 475 of 622 complete. | Added chapais
# Missing data in City Record 476 of 622. | Skipping sidi bu zayd
# City Record 477 of 622 complete. | Added arlit
# City Record 478 of 622 complete. | Added gura vaii
# City Record 479 of 622 complete. | Added port hardy
# City Record 480 of 622 complete. | Added margate
# City Record 481 of 622 complete. | Added marzuq
# City Record 482 of 622 complete. | Added cordoba
# City Record 483 of 622 complete. | Added santa rosalia
# City Record 484 of 622 complete. | Added fairbanks
# City Record 485 of 622 complete. | Added batemans bay
# City Record 486 of 622 complete. | Added saint-louis
# City Record 487 of 622 complete. | Added qixingtai
# City Record 488 of 622 complete. | Added taksimo
# City Record 489 of 622 complete. | Added kirakira
# City Record 490 of 622 complete. | Added kamen-rybolov
# City Record 491 of 622 complete. | Added concepcion del uruguay
# City Record 492 of 622 complete. | Added kovdor
# City Record 493 of 622 complete. | Added souillac
# City Record 494 of 622 complete. | Added north bend
# City Record 495 of 622 complete. | Added lichuan
# City Record 496 of 622 complete. | Added necochea
# City Record 497 of 622 complete. | Added smidovich
# City Record 498 of 622 complete. | Added picota
# City Record 499 of 622 complete. | Added dudinka
# City Record 500 of 622 complete. | Added gat
# City Record 501 of 622 complete. | Added miandrivazo
# City Record 502 of 622 complete. | Added san lazaro
# City Record 503 of 622 complete. | Added bonthe
# City Record 504 of 622 complete. | Added sangueya
# City Record 505 of 622 complete. | Added muzhi
# City Record 506 of 622 complete. | Added maunabo
# City Record 507 of 622 complete. | Added maniitsoq
# City Record 508 of 622 complete. | Added bubaque
# City Record 509 of 622 complete. | Added tura
# City Record 510 of 622 complete. | Added kassala
# City Record 511 of 622 complete. | Added xining
# City Record 512 of 622 complete. | Added bulungu
# City Record 513 of 622 complete. | Added nabire
# City Record 514 of 622 complete. | Added malangwa
# City Record 515 of 622 complete. | Added saraland
# City Record 516 of 622 complete. | Added tilichiki
# City Record 517 of 622 complete. | Added gap
# City Record 518 of 622 complete. | Added ancud
# City Record 519 of 622 complete. | Added manggar
# City Record 520 of 622 complete. | Added whitehorse
# City Record 521 of 622 complete. | Added moranbah
# City Record 522 of 622 complete. | Added westport
# City Record 523 of 622 complete. | Added polson
# City Record 524 of 622 complete. | Added murchison
# City Record 525 of 622 complete. | Added manaus
# City Record 526 of 622 complete. | Added pietarsaari
# City Record 527 of 622 complete. | Added panlaitan
# City Record 528 of 622 complete. | Added qovlar
# City Record 529 of 622 complete. | Added tateyama
# City Record 530 of 622 complete. | Added baoshan
# City Record 531 of 622 complete. | Added yuzhno-kurilsk
# City Record 532 of 622 complete. | Added bardiyah
# City Record 533 of 622 complete. | Added mathathane
# City Record 534 of 622 complete. | Added montepuez
# City Record 535 of 622 complete. | Added yermakovskoye
# City Record 536 of 622 complete. | Added redwater
# Missing data in City Record 537 of 622. | Skipping mendahara
# City Record 538 of 622 complete. | Added charlestown
# City Record 539 of 622 complete. | Added cayenne
# City Record 540 of 622 complete. | Added buala
# City Record 541 of 622 complete. | Added grand-santi
# City Record 542 of 622 complete. | Added bady bassitt
# City Record 543 of 622 complete. | Added gamba
# City Record 544 of 622 complete. | Added tezu
# City Record 545 of 622 complete. | Added gold coast
# City Record 546 of 622 complete. | Added vao
# City Record 547 of 622 complete. | Added evensk
# City Record 548 of 622 complete. | Added ruteng
# Missing data in City Record 549 of 622. | Skipping alipur duar
# City Record 550 of 622 complete. | Added moose factory
# Missing data in City Record 551 of 622. | Skipping ondorhaan
# City Record 552 of 622 complete. | Added ballina
# City Record 553 of 622 complete. | Added cabedelo
# City Record 554 of 622 complete. | Added para de minas
# City Record 555 of 622 complete. | Added sal rei
# City Record 556 of 622 complete. | Added storm lake
# City Record 557 of 622 complete. | Added dalvik
# City Record 558 of 622 complete. | Added almenara
# City Record 559 of 622 complete. | Added te anau
# City Record 560 of 622 complete. | Added pendleton
# City Record 561 of 622 complete. | Added nowy targ
# City Record 562 of 622 complete. | Added sao lourenco do oeste
# City Record 563 of 622 complete. | Added okha
# City Record 564 of 622 complete. | Added kemijarvi
# City Record 565 of 622 complete. | Added sao joao da barra
# Missing data in City Record 566 of 622. | Skipping saryshagan
# City Record 567 of 622 complete. | Added buraydah
# City Record 568 of 622 complete. | Added kristiansund
# City Record 569 of 622 complete. | Added perama
# City Record 570 of 622 complete. | Added panama city
# Missing data in City Record 571 of 622. | Skipping saleaula
# City Record 572 of 622 complete. | Added flinders
# City Record 573 of 622 complete. | Added dafeng
# City Record 574 of 622 complete. | Added aswan
# City Record 575 of 622 complete. | Added botwood
# City Record 576 of 622 complete. | Added nakamura
# City Record 577 of 622 complete. | Added muzaffarpur
# City Record 578 of 622 complete. | Added sirpur
# City Record 579 of 622 complete. | Added camopi
# City Record 580 of 622 complete. | Added quthing
# City Record 581 of 622 complete. | Added ailigandi
# City Record 582 of 622 complete. | Added svetlyy
# City Record 583 of 622 complete. | Added zyryanovsk
# City Record 584 of 622 complete. | Added staicele
# City Record 585 of 622 complete. | Added balkanabat
# City Record 586 of 622 complete. | Added yarada
# City Record 587 of 622 complete. | Added dingli
# City Record 588 of 622 complete. | Added svetlaya
# City Record 589 of 622 complete. | Added conakry
# City Record 590 of 622 complete. | Added townsend
# Missing data in City Record 591 of 622. | Skipping warqla
# City Record 592 of 622 complete. | Added lady frere
# City Record 593 of 622 complete. | Added tucupita
# City Record 594 of 622 complete. | Added soe
# City Record 595 of 622 complete. | Added lompoc
# City Record 596 of 622 complete. | Added berlevag
# City Record 597 of 622 complete. | Added plettenberg bay
# Missing data in City Record 598 of 622. | Skipping jiroft
# City Record 599 of 622 complete. | Added hun
# Missing data in City Record 600 of 622. | Skipping dera din panah
# City Record 601 of 622 complete. | Added sechura
# City Record 602 of 622 complete. | Added phek
# City Record 603 of 622 complete. | Added pundaguitan
# Missing data in City Record 604 of 622. | Skipping makung
# Missing data in City Record 605 of 622. | Skipping gurgan
# City Record 606 of 622 complete. | Added the pas
# City Record 607 of 622 complete. | Added yar-sale
# Missing data in City Record 608 of 622. | Skipping tocantinopolis
# City Record 609 of 622 complete. | Added garowe
# City Record 610 of 622 complete. | Added yumen
# City Record 611 of 622 complete. | Added sisimiut
# City Record 612 of 622 complete. | Added loa janan
# City Record 613 of 622 complete. | Added salinas
# City Record 614 of 622 complete. | Added fonseca
# City Record 615 of 622 complete. | Added nioro
# City Record 616 of 622 complete. | Added sidney
# City Record 617 of 622 complete. | Added tabou
# City Record 618 of 622 complete. | Added pacifica
# City Record 619 of 622 complete. | Added saint-francois
# City Record 620 of 622 complete. | Added cape canaveral
# City Record 621 of 622 complete. | Added havoysund
# City Record 622 of 622 complete. | Added sri aman
# ------------------------------
# End of Records
# ------------------------------

# %%
city_data_df = pd.DataFrame({'City': City_name,
                            'Temperature': Temperature,
                            'Humidity': Humidity,
                            'Cloudiness': Cloudiness,
                            'Wind Speed': Wind_Speed,
                            'Latitude': Latitude,
                            'Latitude': lng})

pd.DataFrame.to_csv(city_data_df, 'city_data.csv')
city_data_df
# Out:
#                 City  Temperature  Humidity  Cloudiness  Wind Speed  Latitude
# 0     Saint-Philippe        73.98        78         100       12.75    -21.36
# 1         Hambantota        80.76        80           0       14.70      6.12
# 2         Kaitangata        52.00        89          90       22.93    -46.28
# 3          Saskylakh        20.10        96         100        5.41     71.92
# 4    Arraial do Cabo        87.73        66           0       20.80    -22.97
# ..               ...          ...       ...         ...         ...       ...
# 564         Pacifica        49.87        76           1       11.41     37.61
# 565   Saint-François        57.63        47           1       14.99     46.42
# 566   Cape Canaveral        82.42        74           1        6.93     28.41
# 567        Havøysund        24.58        62          90        8.05     71.00
# 568         Sri Aman        77.00       100          19        3.33      1.24
#
# [569 rows x 6 columns]

# %%
#Plot latitude vs temperature and save as .png
plt.scatter(city_data_df['Latitude'], city_data_df['Temperature'])
plt.title(f'City Latitude vs. Temperature {date.today()}')
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.grid(True)
plt.savefig('lat_temp.png', bbox_inches='tight')

# %%
#Plot latitude vs humidity and save as .png
plt.scatter(city_data_df['Latitude'], city_data_df['Humidity'])
plt.title(f'City Latitude vs. Humidity {date.today()}')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)
plt.savefig('lat_humid.png', bbox_inches='tight')

# %%
#Plot latitude vs cloudiness and save as .png
plt.scatter(city_data_df['Latitude'], city_data_df['Cloudiness'])
plt.title(f'City Latitude vs. Cloudiness {date.today()}')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)
plt.savefig('lat_cloud.png', bbox_inches='tight')

# %%
#Plot latitude vs wind speed and save as .png
plt.scatter(city_data_df['Latitude'], city_data_df['Wind Speed'])
plt.title(f'City Latitude vs. Wind Speed {date.today()}')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid(True)
plt.savefig('lat_wind.png', bbox_inches='tight')

# %%
#Create DataFrame just for Nothern Hemisphere
Northern_Lat=[lat for lat in Latitude if lat >= 0]
Northern_city_data_df = pd.DataFrame.from_dict({'City': City_name,
                            'Temperature': Temperature,
                            'Humidity': Humidity,
                            'Cloudiness': Cloudiness,
                            'Wind Speed': Wind_Speed,
                            'Latitude': Northern_Lat},orient='index')

Northern_city_data_df=Northern_city_data_df.transpose().dropna()
Northern_city_data_df.head()
# Out:
#               City Temperature Humidity Cloudiness Wind Speed Latitude
# 0  Tirumullaivāsal       80.51       77         30       9.89    11.23
# 1           Mackay       74.93       73         40      13.87    35.44
# 2        Van Buren        46.4       87         90       9.17     8.25
# 3          Gambēla       79.07       63         76        2.8    12.18
# 4            Vaini        75.2       94         90      13.87    50.72

# %%
#Northern Hemisphere Temperature vs. Latitude
x_values = Northern_city_data_df['Latitude'].astype(float)
y_values = Northern_city_data_df['Temperature'].astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.title(f'Nothern Latitude Temperature {date.today()}')
plt.show()

# %%
#Northern Hemisphere  Humidity vs. Latitude
x_values = Northern_city_data_df['Latitude'].astype(float)
y_values = Northern_city_data_df['Humidity'].astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(8,15),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title(f'Nothern Latitude  Humidity {date.today()}')
plt.show()

# %%
#Northern Hemisphere Cloudiness vs. Latitude
x_values = Northern_city_data_df['Latitude'].astype(float)
y_values = Northern_city_data_df['Cloudiness'].astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(8,15),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title(f'Nothern Latitude vs Cloudiness {date.today()}')
plt.show()

# %%
Southern_Lat=[lat for lat in Latitude if lat <= 0]
Southern_city_data_df = pd.DataFrame.from_dict({'City': City_name,
                            'Temperature': Temperature,
                            'Humidity': Humidity,
                            'Cloudiness': Cloudiness,
                            'Wind Speed': Wind_Speed,
                            'Latitude': Southern_Lat}, orient='index')

Southern_city_data_df=Southern_city_data_df.transpose().dropna()
Southern_city_data_df.head()
# Out:
#               City Temperature Humidity Cloudiness Wind Speed Latitude
# 0  Tirumullaivāsal       80.51       77         30       9.89   -21.15
# 1           Mackay       74.93       73         40      13.87    -21.2
# 2        Van Buren        46.4       87         90       9.17    -54.8
# 3          Gambēla       79.07       63         76        2.8    -0.74
# 4            Vaini        75.2       94         90      13.87   -42.88

# %%
x_values = Southern_city_data_df['Latitude'].astype(float)
y_values = Southern_city_data_df['Temperature'].astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.title(f'Southern Latitude Temperature {date.today()}')
plt.show()

# %%
#Southern Hemisphere  Humidity vs. Latitude
x_values = Southern_city_data_df['Latitude'].astype(float)
y_values = Southern_city_data_df['Humidity'].astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(8,15),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title(f'Southern Latitude  Humidity {date.today()}')
plt.show()

# %%
#Southern Hemisphere Cloudiness vs. Latitude
x_values = Southern_city_data_df['Latitude'].astype(float)
y_values = Southern_city_data_df['Cloudiness'].astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(8,15),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title(f'Southern Latitude vs Cloudiness {date.today()}')
plt.show()
